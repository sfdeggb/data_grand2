# %%
# 请求报文
# 多条数据，一般用于推荐类模型
request_data = {
    "requestId":"90acdc24-ddb1-4d12-ab2d-868289a90117",
    "accessToken": "mib",
    "requestTime": 0,
    "resultLimit": 2,
    "commonFeatures": {
        "bill_fee1": 7840.0,
        "bill_fee2": 7800.0,
        "bill_fee3": 7800.0,
        "gsm_zj1": 8.0,
        "gsm_consume2_gap": 990.0,
        "gsm_consume2_redio": 10.989010989010989,
        "qy_sc_view_seq": [
            {"sku_id":"1001","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1002","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1003","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1004","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1005","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
        ],
        "qy_sc_click_seq": [
            {"sku_id":"1001","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1002","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1003","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1004","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1005","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
        ],
        "qy_sc_buy_seq": [
            {"sku_id":"1001","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1002","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1003","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1004","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
            {"sku_id":"1005","oper_time":"20241201","is_add_buy":"1","frist_order_type":"食品","second_order_type":"速溶咖啡"},
        ]
    },
    "rawInstances": [
        {
            "id": "220@126336@20210119309784@0",
            "rawFeatures": {
                "sku_id": "1001",
                "class_name": "20241201",
                "c_price": "1",
                "line_price": "1",
                "goods_class_id": "1",
                "goods_class_name": "1",
                "goods_7day_views": "1",
                "goods_14day_views": "1",
                "goods_30day_views": "1",
                "goods_7day_sales": "1",
                "goods_14day_sales": "1",
                "goods_30day_sales": "1",
            }
        },
        {
            "id": "220@126336@20210119309784@0",
            "rawFeatures": {
                "sku_id": "1002",
                "class_name": "20241201",
                "c_price": "1",
                "line_price": "1",
                "goods_class_id": "1",
                "goods_class_name": "1",
                "goods_7day_views": "1",
                "goods_14day_views": "1",
                "goods_30day_views": "1",
                "goods_7day_sales": "1",
                "goods_14day_sales": "1",
                "goods_30day_sales": "1",
            }
        },
        {
            "id": "220@126336@20210119309784@0",
            "rawFeatures": {
                "sku_id": "1003",
                "class_name": "20241201",
                "c_price": "1",
                "line_price": "1",
                "goods_class_id": "1",
                "goods_class_name": "1",
                "goods_7day_views": "1",
                "goods_14day_views": "1",
                "goods_30day_views": "1",
                "goods_7day_sales": "1",
                "goods_14day_sales": "1",
                "goods_30day_sales": "1",
            }
        }
    ]
}
